# %%
# Add the dependencies.
import pandas as pd
import os
import gmaps
import requests

# %%
# Files to load
LoL_data_to_load = os.path.join("c:", os.sep, "Users", "Juijie", "Desktop", "Analysis Projects", "Final", "LPL 2019 Summer.CSV")


print(LoL_data_to_load)
# Out:
# c:\Users\Juijie\Desktop\Analysis Projects\Final\LPL 2019 Summer.CSV

# %%
LPL_data_df = pd.read_csv(LoL_data_to_load)
LPL_data_df
# Out:
#       Player             Team     Pos  GP   W% CTR%    K    D    A  KDA  ...  \
# 0        369      Top Esports     Top  31  71%  42%   84   77  161  3.2  ...
# 1        957          Team WE     Top   1   0%   0%    1    3    3  1.3  ...
# 2        ADD  Bilibili Gaming     Top  35  66%  51%   92  104  186  2.7  ...
# 3        Aix      Vici Gaming  Jungle  23  35%  48%   48   67  135  2.7  ...
# 4        Aki      Top Esports  Jungle   6  67%  50%   10   16   54  4.0  ...
# ..       ...              ...     ...  ..  ...  ...  ...  ...  ...  ...  ...
# 121    Yagao        JD Gaming  Middle  36  47%  50%  109   93  211  3.4  ...
# 122  Youdang      Vici Gaming  Jungle  15  20%  53%   23   46   59  1.8  ...
# 123    Yuuki       LGD Gaming  Middle  37  30%  62%   86  108  184  2.5  ...
# 124     Zoom        JD Gaming     Top  33  45%  42%   69   85  169  2.8  ...
# 125    ZWuJi   Rogue Warriors     ADC  37  35%  51%  115   81  176  3.6  ...
#
# ...

# %%
#Clean and drop the columns with NaN data

df1 = pd.DataFrame(LPL_data_df)
df=df1.drop(['D%P15','STL'],axis=1)

# %%
# The player who played most games in 2019 Summer Season
major_player_df= df[LPL_data_df["GP"] >= 30]
major_player_df.head(5)
# Out:
#       Player             Team      Pos  GP   W% CTR%    K    D    A  KDA  ...  \
# 0        369      Top Esports      Top  31  71%  42%   84   77  161  3.2  ...
# 2        ADD  Bilibili Gaming      Top  35  66%  51%   92  104  186  2.7  ...
# 9      Asura      LNG Esports      ADC  36  53%  47%  151   74  167  4.3  ...
# 11    Baolan  Invictus Gaming  Support  33  58%  42%   25   89  334  4.0  ...
# 12  beishang          Team WE   Jungle  37  51%  41%   94  101  254  3.4  ...
#
#    CSD10 CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 0    0.8  8.4  26.9%  483  24.9%   276  22.4%  0.39  0.14  0.16
# 2   -3.8  7.6  23.7%  486  24.5%   256  21.4%  0.53  0.20  0.22
# 9   -3.9  9.6  31.1%  561  31.2%   320  27.2%  0.32  0.08  0.28
# 11  -1.6  1.2   3.9%  212  10.0%   124  10.0%  1.30  0.48  0.24
# 12   3.5  5.2  14.4%  299  15.1%   206  17.1%  0.51  0.35  0.44
#
# [5 rows x 26 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Sort the players by KDA 

KDA_df = major_player.sort_values(by=["KDA"],ascending=False)
KDA_df.head(5)
# Out:
#      Player                 Team      Pos  GP   W% CTR%    K   D    A  KDA  \
# 107     Uzi  Royal Never Give Up      ADC  35  71%  74%  161  67  214  5.6
# 114  Xiaohu  Royal Never Give Up   Middle  35  71%  54%  141  73  243  5.3
# 80     Ming  Royal Never Give Up  Support  35  71%  37%   39  73  338  5.2
# 59    Karsa  Royal Never Give Up   Jungle  35  71%  46%  102  79  293  5.0
# 78    Meiko        EDward Gaming  Support  35  60%  49%   31  79  350  4.8
#
#      ... CS%P15  DPM   DMG% D%P15  EGPM  GOLD%  STL   WPM  CWPM  WCPM
# 107  ...  36.0%  562  30.7%   NaN   352  29.2%  NaN  0.42  0.14  0.51
# 114  ...  22.2%  489  26.9%   NaN   269  22.4%  NaN  0.35  0.21  0.27
# 80   ...   4.6%  176   9.7%   NaN   131  10.9%  NaN  1.75  0.55  0.32
# 59   ...  12.1%  257  14.0%   NaN   204  16.9%  NaN  0.82  0.43  0.46
# 78   ...   4.7%  197  10.8%   NaN   130  10.8%  NaN  1.40  0.47  0.30
#
# [5 rows x 28 columns]

# %%
# Sort the players by KDA 
KDA_df.tail(5)
# Out:
#      Player            Team      Pos  GP   W% CTR%   K    D    A  KDA  ...  \
# 91     Poss         Team WE      Top  35  51%  77%  65  104  196  2.5  ...
# 123   Yuuki      LGD Gaming   Middle  37  30%  62%  86  108  184  2.5  ...
# 90     poge    Victory Five  Support  35  34%  31%  27  125  264  2.3  ...
# 75     MaiX  Rogue Warriors   Middle  36  36%  42%  86  122  159  2.0  ...
# 42   Holder  Rogue Warriors      Top  37  35%  57%  84  117  129  1.8  ...
#
#     CS%P15  DPM   DMG% D%P15  EGPM  GOLD%  STL   WPM  CWPM  WCPM
# 91   22.1%  352  18.2%   NaN   232  19.3%  NaN  0.44  0.22  0.13
# 123  24.5%  410  24.1%   NaN   242  22.9%  NaN  0.38  0.19  0.27
# 90    6.7%  187  10.0%   NaN   117  10.5%  NaN  1.21  0.35  0.34
# 75   26.6%  403  23.6%   NaN   258  23.6%  NaN  0.51  0.22  0.20
# 42   24.0%  330  19.6%   NaN   243  22.1%  NaN  0.44  0.14  0.19
#
# [5 rows x 28 columns]

# %%
# The player on TOP position rank by KDA 
Top_player_df=major_player_df[df["Pos"]=='Top'].sort_values(by=["KDA"],ascending=False)
Top_player_df.head(5)
# Out:
# C:\Users\Juijie\AppData\Local\Temp/ipykernel_2856/2540169435.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Top_player_df=major_player_df[df["Pos"]=='Top'].sort_values(by=["KDA"],ascending=False)
#      Player                 Team  Pos  GP   W% CTR%    K    D    A  KDA  ...  \
# 38  GimGoon      FunPlus Phoenix  Top  33  88%  45%  110   58  224  5.8  ...
# 66    Langx  Royal Never Give Up  Top  31  74%  55%   85   59  135  3.7  ...
# 56    Jinoo        EDward Gaming  Top  35  60%  46%  111   84  190  3.6  ...
# 0       369          Top Esports  Top  31  71%  42%   84   77  161  3.2  ...
# 33  Flandre          LNG Esports  Top  36  53%  50%  103  101  193  2.9  ...
#
#    CSD10 CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 38  -6.0  7.5  22.2%  430  20.9%   269  20.4%  0.45  0.14  0.18
# 66  -4.4  8.3  25.6%  332  18.7%   255  21.0%  0.46  0.15  0.20
# 56   3.6  7.8  25.0%  435  23.4%   261  22.1%  0.50  0.24  0.28
# ...

# %%
# The player on MIDDLE position rank by KDA 
Mid_player_df=major_player_df[df["Pos"]=='Middle'].sort_values(by=["KDA"],ascending=False)
Mid_player_df.head(5)
# Out:
# C:\Users\Juijie\AppData\Local\Temp/ipykernel_2856/45818079.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Mid_player_df=major_player_df[df["Pos"]=='Middle'].sort_values(by=["KDA"],ascending=False)
#      Player                 Team     Pos  GP   W% CTR%    K   D    A  KDA  \
# 27    Doinb      FunPlus Phoenix  Middle  33  88%  70%  147  75  260  5.4
# 114  Xiaohu  Royal Never Give Up  Middle  35  71%  54%  141  73  243  5.3
# 65     Kuro      Bilibili Gaming  Middle  35  66%  54%  109  66  209  4.8
# 98    Scout        EDward Gaming  Middle  35  60%  54%  147  72  195  4.8
# 61   knight          Top Esports  Middle  35  69%  63%  155  76  162  4.2
#
#      ... CSD10 CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 27   ...   0.2  8.7  27.0%  477  23.0%   309  23.4%  0.42  0.14  0.23
# 114  ...   2.9  8.1  22.2%  489  26.9%   269  22.4%  0.35  0.21  0.27
# 65   ...  -5.1  8.3  23.8%  487  23.7%   266  22.1%  0.55  0.24  0.31
# ...

# %%
# The player on JUNGLE position rank by KDA 
Jungle_player_df=major_player_df[df["Pos"]=='Jungle'].sort_values(by=["KDA"],ascending=False)
Jungle_player_df.head(5)
# Out:
# C:\Users\Juijie\AppData\Local\Temp/ipykernel_2856/997754507.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Jungle_player_df=major_player_df[df["Pos"]=='Jungle'].sort_values(by=["KDA"],ascending=False)
#      Player                 Team     Pos  GP   W% CTR%    K   D    A  KDA  \
# 105    Tian      FunPlus Phoenix  Jungle  33  88%  33%  118  78  289  5.2
# 59    Karsa  Royal Never Give Up  Jungle  35  71%  46%  102  79  293  5.0
# 79   Meteor      Bilibili Gaming  Jungle  35  66%  46%  123  85  231  4.2
# 54   Jiejie        EDward Gaming  Jungle  35  60%  66%   81  93  272  3.8
# 100    SofM          LNG Esports  Jungle  36  53%  50%   85  93  238  3.5
#
#      ... CSD10 CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 105  ...   2.9  5.3  14.6%  367  17.6%   237  17.9%  0.69  0.36  0.46
# 59   ...  -0.1  4.8  12.1%  257  14.0%   204  16.9%  0.82  0.43  0.46
# 79   ...   1.0  5.5  15.4%  336  16.4%   227  19.0%  0.75  0.36  0.46
# ...

# %%
# The player on SUPPORT position rank by KDA 
Support_player_df=major_player_df[df["Pos"]=='Support'].sort_values(by=["KDA"],ascending=False)
Support_player_df.head(5)
# Out:
# C:\Users\Juijie\AppData\Local\Temp/ipykernel_2856/2555707193.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Support_player_df=major_player_df[df["Pos"]=='Support'].sort_values(by=["KDA"],ascending=False)
#      Player                 Team      Pos  GP   W% CTR%   K   D    A  KDA  \
# 25    Crisp      FunPlus Phoenix  Support  33  88%  70%  47  76  365  5.4
# 80     Ming  Royal Never Give Up  Support  35  71%  37%  39  73  338  5.2
# 78    Meiko        EDward Gaming  Support  35  60%  49%  31  79  350  4.8
# 116   XinMo      Bilibili Gaming  Support  35  66%  49%  27  78  304  4.2
# 11   Baolan      Invictus Gaming  Support  33  58%  42%  25  89  334  4.0
#
#      ... CSD10 CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 25   ...  -2.8  1.3   4.3%  198   9.6%   150  11.3%  1.45  0.46  0.32
# 80   ...   0.4  1.4   4.6%  176   9.7%   131  10.9%  1.75  0.55  0.32
# 78   ...  -3.1  1.2   4.7%  197  10.8%   130  10.8%  1.40  0.47  0.30
# ...

# %%
# The player on ADC position rank by KDA 
ADC_player_df=major_player_df[df["Pos"]=='ADC'].sort_values(by=["KDA"],ascending=False)
ADC_player_df.head(5)
# Out:
# C:\Users\Juijie\AppData\Local\Temp/ipykernel_2856/769496058.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ADC_player_df=major_player_df[df["Pos"]=='ADC'].sort_values(by=["KDA"],ascending=False)
#       Player                 Team  Pos  GP   W% CTR%    K   D    A  KDA  ...  \
# 73       Lwx      FunPlus Phoenix  ADC  33  88%  58%  210  59  189  6.8  ...
# 107      Uzi  Royal Never Give Up  ADC  35  71%  74%  161  67  214  5.6  ...
# 48      iBoy        EDward Gaming  ADC  33  64%  42%  133  61  197  5.4  ...
# 69     LokeN          Top Esports  ADC  35  69%  49%  114  63  179  4.7  ...
# 55   Jinjiao      Bilibili Gaming  ADC  35  66%  31%  132  70  181  4.5  ...
#
#     CSD10  CSPM CS%P15  DPM   DMG%  EGPM  GOLD%   WPM  CWPM  WCPM
# 73    7.2   9.9  31.9%  607  28.9%   359  27.0%  0.33  0.09  0.38
# 107   7.3  10.7  36.0%  562  30.7%   352  29.2%  0.42  0.14  0.51
# 48    6.2   9.5  32.4%  501  26.7%   326  27.2%  0.39  0.12  0.47
# ...

# %%
best_team_df =major_player_df.sort_values(by=["W%"],ascending=False)
best_team_df.head(15)
# Out:
#       Player                 Team      Pos  GP   W% CTR%    K    D    A  KDA  \
# 38   GimGoon      FunPlus Phoenix      Top  33  88%  45%  110   58  224  5.8
# 73       Lwx      FunPlus Phoenix      ADC  33  88%  58%  210   59  189  6.8
# 105     Tian      FunPlus Phoenix   Jungle  33  88%  33%  118   78  289  5.2
# 25     Crisp      FunPlus Phoenix  Support  33  88%  70%   47   76  365  5.4
# 27     Doinb      FunPlus Phoenix   Middle  33  88%  70%  147   75  260  5.4
# 66     Langx  Royal Never Give Up      Top  31  74%  55%   85   59  135  3.7
# 0        369          Top Esports      Top  31  71%  42%   84   77  161  3.2
# 107      Uzi  Royal Never Give Up      ADC  35  71%  74%  161   67  214  5.6
# 80      Ming  Royal Never Give Up  Support  35  71%  37%   39   73  338  5.2
# 59     Karsa  Royal Never Give Up   Jungle  35  71%  46%  102   79  293  5.0
# 114   Xiaohu  Royal Never Give Up   Middle  35  71%  54%  141   73  243  5.3
# ...
